# %%
# !git clone git@github.com:spring-projects/spring-petclinic.git repos/spring-petclinic
# Out:
# Cloning into 'repos/spring-petclinic'...
# remote: Enumerating objects: 10819, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 10819 (delta 0), reused 0 (delta 0), pack-reused 10814 (from 2)
# Receiving objects: 100% (10819/10819), 10.22 MiB | 10.01 MiB/s, done.
# Resolving deltas: 100% (4095/4095), done.

# %%
# !cp run_repos_find.sh repos/spring-petclinic/repos_find.sh
# !cd repos/spring-petclinic && chmod +x repos_find.sh && ./repos_find.sh
# Out:
# [INFO] -> Repositório não encontrado
# [INFO] -> Repositório não encontrado
# The -> Repositório não encontrado
# org.springframework.boot:spring-boot-starter-actuator:jar:3.4.2:compile -> https://github.com/spring-projects/spring-boot
# org.springframework.boot:spring-boot-starter:jar:3.4.2:compile -> https://github.com/spring-projects/spring-boot
# org.springframework.boot:spring-boot-starter-logging:jar:3.4.2:compile -> https://github.com/spring-projects/spring-boot
# ch.qos.logback:logback-classic:jar:1.5.16:compile -> https://github.com/qos-ch/logback/logback-classic
# ch.qos.logback:logback-core:jar:1.5.16:compile -> https://github.com/qos-ch/logback/logback-core
# org.apache.logging.log4j:log4j-to-slf4j:jar:2.24.3:compile -> https://github.com/apache/logging-log4j2
# org.apache.logging.log4j:log4j-api:jar:2.24.3:compile -> https://github.com/apache/logging-log4j2
# org.slf4j:jul-to-slf4j:jar:2.0.16:compile -> https://github.com/qos-ch/slf4j/slf4j-parent/jul-to-slf4j
# ...

# %%
# !git clone https://github.com/spring-projects/spring-boot repos/spring-boot
# !git clone https://github.com/qos-ch/logback repos/logback
# !git clone https://github.com/apache/logging-log4j2 repos/logging-log4j2
# !git clone https://github.com/qos-ch/slf4j repos/slf4j
# !git clone https://github.com/jakartaee/common-annotations-api repos/common-annotations-api
# !git clone https://bitbucket.org/snakeyaml/snakeyaml/src repos/snakeyaml
# !git clone http://github.com/FasterXML/jackson-modules-java8/jackson-datatype-jsr310 repos/jackson-datatype-jsr310
# !git clone https://github.com/spring-projects/spring-framework repos/spring-framework
# !git clone https://github.com/brettwooldridge/HikariCP repos/HikariCP
# !git clone https://github.com/hibernate/hibernate-orm repos/hibernate-orm
# !git clone https://github.com/jakartaee/persistence.git repos/persistence
# !git clone https://github.com/eclipse-ee4j/jta-api repos/jta-api
# !git clone https://github.com/jboss-logging/jboss-logging repos/jboss-logging
# !git clone https://github.com/FasterXML/java-classmate repos/java-classmate
# !git clone https://github.com/antlr/antlr4 repos/antlr4
# !git clone https://github.com/spring-projects/spring-data-jpa repos/spring-data-jpa
# !git clone https://github.com/spring-projects/spring-data-commons repos/spring-data-commons
# !git clone https://github.com/qos-ch/slf4j repos/slf4j-api
# !git clone https://github.com/eclipse/org.aspectj repos/org.aspectj
# !git clone http://github.com/FasterXML/jackson-modules-java8/jackson-datatype-jdk8 repos/jackson-datatype-jdk8
# !git clone https://github.com/hibernate/hibernate-validator repos/hibernate-validator
# !git clone https://github.com/jakartaee/validation repos/validation
# !git clone https://github.com/thymeleaf/thymeleaf repos/thymeleaf
# !git clone https://github.com/reactor/reactor-core repos/reactor-core
# !git clone https://github.com/typetools/checker-framework.git repos/checker-framework
# !git clone https://github.com/ben-manes/caffeine repos/caffeine
# !git clone https://github.com/google/error-prone repos/error-prone
# !git clone https://github.com/webjars/webjars-locator-lite repos/webjars-locator-lite
# !git clone https://github.com/jspecify/jspecify/ repos/jspecify
# !git clone https://github.com/twbs/bootstrap repos/bootstrap
# !git clone https://github.com/FasterXML/jackson-databind repos/jackson-databind
# !git clone https://github.com/FasterXML/jackson-annotations repos/jackson-annotations
# !git clone https://github.com/FasterXML/jackson-core repos/jackson-core
# !git clone http://github.com/FasterXML/jackson-modules-java8/jackson-module-parameter-names repos/jackson-module-parameter-names
# !git clone https://github.com/jakartaee/jaxb-api.git repos/jakarta.xml.bind-api
# !git clone https://github.com/jakartaee/jaf-api repos/jaf-api
# Out:
# Cloning into 'repos/spring-boot'...
# remote: Enumerating objects: 942488, done.
# remote: Counting objects: 100% (407/407), done.
# remote: Compressing objects: 100% (169/169), done.
# remote: Total 942488 (delta 314), reused 238 (delta 238), pack-reused 942081 (from 3)
# Receiving objects: 100% (942488/942488), 179.88 MiB | 31.19 MiB/s, done.
# Resolving deltas: 100% (426336/426336), done.
# Cloning into 'repos/logback'...
# remote: Enumerating objects: 94125, done.
# remote: Counting objects: 100% (7599/7599), done.
# remote: Compressing objects: 100% (929/929), done.
# remote: Total 94125 (delta 7104), reused 6702 (delta 6655), pack-reused 86526 (from 3)
# Receiving objects: 100% (94125/94125), 28.89 MiB | 30.85 MiB/s, done.
# Resolving deltas: 100% (47767/47767), done.
# Cloning into 'repos/logging-log4j2'...
# remote: Enumerating objects: 382324, done.
# remote: Counting objects: 100% (404/404), done.
# remote: Compressing objects: 100% (180/180), done.
# ...

# %%
# !git clone https://github.com/micrometer-metrics/micrometer.git repos/micrometer
# !git clone https://github.com/apache/tomcat.git repos/tomcat
# !git clone https://github.com/attoparser/attoparser.git repos/attoparser
# !git clone https://github.com/unbescape/unbescape.git repos/unbescape
# !git clone https://github.com/reactive-streams/reactive-streams-jvm repos/reactive-streams-jvm
# !git clone https://github.com/jsr107/jsr107spec.git repos/jsr107spec
# Out:
# Cloning into 'repos/micrometer'...
# remote: Enumerating objects: 128058, done.
# remote: Counting objects: 100% (1020/1020), done.
# remote: Compressing objects: 100% (463/463), done.
# remote: Total 128058 (delta 886), reused 560 (delta 554), pack-reused 127038 (from 5)
# Receiving objects: 100% (128058/128058), 35.39 MiB | 6.30 MiB/s, done.
# Resolving deltas: 100% (58337/58337), done.
# Cloning into 'repos/tomcat'...
# remote: Enumerating objects: 556283, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 556283 (delta 62), reused 52 (delta 52), pack-reused 556211 (from 4)
# Receiving objects: 100% (556283/556283), 165.45 MiB | 32.32 MiB/s, done.
# Resolving deltas: 100% (384499/384499), done.
# Cloning into 'repos/attoparser'...
# remote: Enumerating objects: 5139, done.
# remote: Counting objects: 100% (462/462), done.
# remote: Compressing objects: 100% (225/225), done.
# ...

# %%
# !git clone https://github.com/FasterXML/jackson-core.git repos/jackson-core
# Out:
# fatal: destination path 'repos/jackson-core' already exists and is not an empty directory.
